# %% [markdown]
# <a href="https://colab.research.google.com/github/angiee24/AVD-1/blob/main/MINPRO_1_AVD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Analysis of Heart Attack Risk**

# %% [markdown]
# #**Studi Kasus**
#
# "Analisis Faktor Risiko Penyakit Jantung Berdasarkan Data"
#
# Studi ini bertujuan untuk memahami hubungan antara faktor-faktor kesehatan dengan risiko penyakit jantung menggunakan data yang tersedia, menganalisis hubungan antara faktor kesehatan seperti usia, tekanan darah, kolesterol, kebiasaan merokok, dan diabetes terhadap risiko serangan jantung, dan memberikan rekomendasi berbasis data untuk pencegahan dini penyakit jantung.

# %% [markdown]
# # **Business Objective**
#
# Tujuan utama proyek ini adalah untuk menganalisis faktor risiko penyakit jantung guna mendukung inovasi dalam pencegahan dan perawatan kesehatan berbasis data. Dengan memahami hubungan antara faktor-faktor seperti usia, kadar kolesterol, tekanan darah, kebiasaan merokok, status diabetes, dan riwayat serangan jantung, proyek ini bertujuan untuk:
#
# Mengidentifikasi pola dan tren dalam faktor risiko penyakit kardiovaskular, Membangun model prediktif yang dapat membantu tenaga medis dalam mendeteksi risiko penyakit jantung lebih awal, dan memberi wawasan bagi penyedia layanan kesehatan untuk meningkatkan strategi pencegahan dan perawatan yang lebih efektif berdasarkan analisis data pasien.

# %% [markdown]
# # **Assess Situation**
#
# Situasi kesehatan saat ini menunjukkan meningkatnya kasus penyakit jantung sebagai salah satu penyebab utama kematian di seluruh dunia. Faktor risiko seperti pola hidup tidak sehat, kurangnya aktivitas fisik, dan kebiasaan merokok berkontribusi terhadap peningkatan insiden penyakit kardiovaskular. Oleh karena itu, pemanfaatan data kesehatan menjadi penting untuk, Menganalisis tren demografi dan faktor risiko utama dalam populasi tertentu,Mengembangkan pendekatan personalisasi dalam pencegahan penyakit berdasarkan profil risiko individu, dan mengoptimalkan sumber daya perawatan kesehatan dengan memberikan rekomendasi berbasis data untuk intervensi dini.
#
# Selain itu, lingkungan kesehatan modern menghadapi tantangan meningkatnya kasus penyakit jantung akibat pola hidup dan faktor genetik. Analisis ini diperlukan untuk memahami hubungan berikut :
#
# * Usia dan risiko penyakit jantung.
# * Pengaruh tekanan darah terhadap kesehatan jantung.
# * Hubungan antara merokok dan peningkatan risiko serangan jantung.
# * Dampak diabetes terhadap penyakit jantung.

# %% [markdown]
# #**Data Mining Goals**
#
# Tujuan dari pemrosesan data adalah untuk mengidentifikasi pola dalam faktor risiko penyakit jantung melalui teknik analisis data. Beberapa tujuan yaitu :
#
# Menganalisis hubungan antara kadar kolesterol (total, LDL, dan HDL) dengan kemungkinan serangan jantung, Mengidentifikasi dampak tekanan darah tinggi terhadap risiko penyakit jantung, Menentukan korelasi antara kebiasaan merokok dan diabetes terhadap peningkatan risiko penyakit kardiovaskular, dan untuk mendeteksi individu dengan risiko tinggi mengalami serangan jantung berdasarkan atribut kesehatan mereka.

# %% [markdown]
# #**Project Plan**
#
# Mengumpulkan Data: Menggunakan dataset yang berisi 1.000 catatan pasien dengan berbagai indikator kesehatan.
#
# Analisis Data: Melakukan eksplorasi data untuk memahami distribusi variabel dan hubungan antar faktor risiko.
#
# Preprocessing Data: Membersihkan data, menangani data yang hilang (jika ada), dan melakukan perbaikan data jika diperlukan.
#
# Visualisasi : Proses menggunakan elemen visual seperti diagram, grafik, atau peta untuk mempresentasikan data.
#
# Dashboard : Menyajikan data dari berbagai perspektif dalam satu halaman.
#
# Insight dan Action : Meringkas, menyimpulkan dan membuat keputusan dari data yang sudah diolah
#
# Interpretasi & Implementasi: Menyediakan hasil akhir berdasarkan hasil analisis untuk digunakan dalam strategi pencegahan dan pengelolaan penyakit jantung oleh tenaga kesehatan.

# %%
import pandas as pd

csv_path = "/content/drive/MyDrive/AVD/updated_version.csv"
df = pd.read_csv(csv_path)

df.head()
# Out:
#    age  sex  total_cholesterol         ldl        hdl  systolic_bp  \
# 0   57    1         229.463642  175.879129  39.225687   124.070127
# 1   58    1         186.464120  128.984916  34.950968    95.492552
# 2   37    1         251.300719  152.347592  45.913288    99.519335
# 3   55    1         192.058908  116.803684  67.208925   122.460002
# 4   53    1         151.203448  107.017396  60.693838   123.022257
#
#    diastolic_bp  smoking  diabetes  heart_attack
# 0     91.378780        0         0             0
# 1     64.355040        1         0             0
# 2     64.953147        0         1             0
# 3     73.821382        0         0             0
# 4     81.121946        0         1             0
